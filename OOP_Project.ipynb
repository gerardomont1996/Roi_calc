# %%
#BOX1 #Rental Income, Laundry, Storage,Miscleoius=0 #Duplex print("Welcome") print ("Please exclude any currency signs,commas,or decimal points in your input")
class Roi_calc():
    def init(self,rental,laundry,storage,miscellaneous,total_income):
            self.rental=rental 
            self.laudry=laundry 
            self.storage=storage 
            self.miscellaneous=misc 
            self.total_income=total_income 
    def income(self):   
        rental=int(input ("What is your monthly rental income?")) 
        ask=input('Do you have any income from laundry,storage or miscellanoeus? "yes" or "no"') 
        if ask == "yes" : laundry=int(input("What is your monthly laundry income?")) 
        storage =int(input("What is your storage income?"))
        misc=int(input("What is your miscellaneous?")) 
        total_income=(rental,laundry,storage,misc) 
        total_mothly_income=sum(total) 
        print("===============================================") 
        print(f"Your total monthly income ${sum(total_income)}") 
        print("===============================================")
#BOX2
##Expenses(Taxes,Insurance,Utilities (elec,water,gas)HOA,Lawn/Snow,Vacancy,Repairs,CapEx,property management,mortgage) #add expences def expenses(self): reductions=input("Do you have expenses? 'yes'or 'no'? ")
    def expenses(self):
        if reductions == "yes":
            taxes=int(input('How much are taxes?')) 
            insurance=int(input('How much is insurance?'))
            utilities=int(input("How much is the utilities?"))
            hoa=int(input("How much is the HOA?"))   
            lawn=int(input("How much is the lawn service?"))
            vacancy=int(input("How much is the vancay?"))
            repairs=int(input("How much are the repairs"))             
            morgage=int(input("How much is the morgage?"))
            total_exp=(taxes,insurance, utilities,hoa,lawn,vacancy,repairs,morgage)
            print("============================================")
            print(f'Your total expenses is ${sum(total_exp)}')
            print("=============================================")
        
    #box3 Cashflow  
    def cashflow(self):
        print (f'Your cashflow is ${total_exp-total_income}')






#Box 4 
#Cash on Cash ROI(RETURN ON INVESTMENT) #add Down payment, Closing Cost, Rehab Budget, Misc other= Total Investment #month cash flow x 12(months)=annual cash flow #Annual cash flow divide by Total invesment = (times by 100 add % )=CASH ON CASH ROI def roi(self):
    def cash_on_cash(self):
        downpayment=int(input('How much is the downpayment?'))
        closing_cost=int(input('How much is the closing cost?'))
        rehab_budget=int(input("How much is the rehab?"))

        invest=(downpayment,closing_cost,reahab_budget)
        total_invest=sum(invest)
        print(total_invest)

        annual_cashflow=cashflow*12
        print(annual_cashflow)

        roi= cashflow / total_invest *100 
        print(f'Your total ROI is {roi}')
        
def roi():
    roi=Roi_calc
    roi.expenses
    roi.cashflow
    roi.cash_on_cash
roi()
